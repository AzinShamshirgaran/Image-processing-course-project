# %%
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa
import os
from scipy import signal

# %%
# Expect the sampling rate to be the same for all recordings.
sampling_rate_expected = 44100

# The window size for the spectrogram.
window_size = 1024

# The window overlap for the spectrogram.
window_overlap = 512

# %%
# The directory where the .wav files are located. We will read these.
recording_dir = '../../Recordings/'

# The directory where we will write the computed spectrograms as .png image files.
spectrogram_dir = '../../Spectrograms/'

# %%
# Write spectrogram parameters.
parameters_filename = spectrogram_dir + '0_spectrogram_parameters.txt'
spectogram_param_file = open(parameters_filename,'w')
spectogram_param_file.write('sampling rate = '+ repr(sampling_rate_expected)+'\n')
spectogram_param_file.write('window size = '+ repr(window_size)+'\n')
spectogram_param_file.write('window overlap = '+ repr(window_overlap)+'\n')
spectogram_param_file.write('log10 of spectrum\n')
spectogram_param_file.close()

# %%
# Get list of recordings.
recording_list = os.listdir(recording_dir);
n_recordings = len(recording_list)
print(n_recordings)
# Out:
# 171

# %%
# Read each recording and compute spectrogram
recording_num = 0
for recording in recording_list:
    recording_num = recording_num + 1
    recording_filename = recording_dir + recording
    print('recording '+repr(recording_num)+' of '+repr(n_recordings)+': about to read '+recording)
    # Read the audio file. Don't change the sample rate.
    x, sampling_rate = librosa.load(recording_filename,sr=None)
    
    if sampling_rate != sampling_rate_expected:
        print('WRONG SAMPLING RATE: expected='+repr(sampling_rate_expected)+' recording='+repr(sampling_rate))
        break
        
    # Compute the spectrogram.
    w, t, s = signal.spectrogram(x, sampling_rate, noverlap=window_overlap, nperseg=window_size)
    
    # s: matrix with the 2D spectrogram (will be complex).
    # w: vector with the frequencies spacings of the computed DFT.
    # t: vector with the time spacings of the windows.

    # Compute the spectrum of the spectrogram.
    s_spectrum = abs(s);
    
    # Flip it vertically.
    s_spectrum = np.flip(s_spectrum, 0)

    # Compute log_10 of spectrogram.
    s_spectrum_log = np.log10( s_spectrum + np.finfo(float).eps )
    #plt.imshow(s_spectrum_log,cmap='gray')
    
    # Normalize so values range from 0 to 1.
    s_spectrum_log = (s_spectrum_log - np.amin(s_spectrum_log)) / (np.amax(s_spectrum_log) - np.amin(s_spectrum_log))

    # Save as png file.
    spectrogram_filename = spectrogram_dir + recording +'.png'
    plt.imsave(spectrogram_filename, s_spectrum_log, cmap='gray')

    # Save time and frequency indices.
    spectrograminfo_filename = spectrogram_dir + recording + '_info.txt'
    spectrograminfo_file = open(spectrograminfo_filename,'w')    
    for i in t:
        spectrograminfo_file.write(repr(i)+'\n')
    for i in w:
        spectrograminfo_file.write(repr(i)+'\n')
    spectrograminfo_file.close()
# Out:
# recording 1 of 171: about to read 00000.wav
# recording 2 of 171: about to read 00001.wav
# recording 3 of 171: about to read 00002.wav
# recording 4 of 171: about to read 00003.wav
# recording 5 of 171: about to read 00004.wav
# recording 6 of 171: about to read 00005.wav
# recording 7 of 171: about to read 00006.wav
# recording 8 of 171: about to read 00007.wav
# recording 9 of 171: about to read 00008.wav
# recording 10 of 171: about to read 00009.wav
# recording 11 of 171: about to read 00010.wav
# recording 12 of 171: about to read 00011.wav
# recording 13 of 171: about to read 00012.wav
# recording 14 of 171: about to read 00013.wav
# recording 15 of 171: about to read 00014.wav
# recording 16 of 171: about to read 00015.wav
# recording 17 of 171: about to read 00016.wav
# recording 18 of 171: about to read 00017.wav
# recording 19 of 171: about to read 00018.wav
# recording 20 of 171: about to read 00019.wav
# recording 21 of 171: about to read 00020.wav
# recording 22 of 171: about to read 00021.wav
# recording 23 of 171: about to read 00022.wav
# recording 24 of 171: about to read 00023.wav
# recording 25 of 171: about to read 00024.wav
# recording 26 of 171: about to read 00025.wav
# recording 27 of 171: about to read 00026.wav
# recording 28 of 171: about to read 00027.wav
# recording 29 of 171: about to read 00028.wav
# recording 30 of 171: about to read 00029.wav
# recording 31 of 171: about to read 00030.wav
# recording 32 of 171: about to read 00031.wav
# recording 33 of 171: about to read 00032.wav
# recording 34 of 171: about to read 00033.wav
# recording 35 of 171: about to read 00034.wav
# recording 36 of 171: about to read 00035.wav
# recording 37 of 171: about to read 00036.wav
# recording 38 of 171: about to read 00037.wav
# recording 39 of 171: about to read 00038.wav
# recording 40 of 171: about to read 00039.wav
# recording 41 of 171: about to read 00040.wav
# recording 42 of 171: about to read 00041.wav
# recording 43 of 171: about to read 00042.wav
# recording 44 of 171: about to read 00043.wav
# recording 45 of 171: about to read 00044.wav
# recording 46 of 171: about to read 00045.wav
# recording 47 of 171: about to read 00046.wav
# recording 48 of 171: about to read 00047.wav
# recording 49 of 171: about to read 00048.wav
# recording 50 of 171: about to read 00049.wav
# recording 51 of 171: about to read 00050.wav
# recording 52 of 171: about to read 00051.wav
# recording 53 of 171: about to read 00052.wav
# recording 54 of 171: about to read 00053.wav
# recording 55 of 171: about to read 00054.wav
# recording 56 of 171: about to read 00055.wav
# recording 57 of 171: about to read 00056.wav
# recording 58 of 171: about to read 00057.wav
# recording 59 of 171: about to read 00058.wav
# recording 60 of 171: about to read 00059.wav
# recording 61 of 171: about to read 00060.wav
# recording 62 of 171: about to read 00061.wav
# recording 63 of 171: about to read 00062.wav
# recording 64 of 171: about to read 00063.wav
# recording 65 of 171: about to read 00064.wav
# recording 66 of 171: about to read 00065.wav
# recording 67 of 171: about to read 00066.wav
# recording 68 of 171: about to read 00067.wav
# recording 69 of 171: about to read 00068.wav
# recording 70 of 171: about to read 00069.wav
# recording 71 of 171: about to read 00070.wav
# recording 72 of 171: about to read 00071.wav
# recording 73 of 171: about to read 00072.wav
# recording 74 of 171: about to read 00073.wav
# recording 75 of 171: about to read 00074.wav
# recording 76 of 171: about to read 00075.wav
# recording 77 of 171: about to read 00076.wav
# recording 78 of 171: about to read 00077.wav
# recording 79 of 171: about to read 00078.wav
# recording 80 of 171: about to read 00079.wav
# recording 81 of 171: about to read 00080.wav
# recording 82 of 171: about to read 00081.wav
# recording 83 of 171: about to read 00082.wav
# recording 84 of 171: about to read 00083.wav
# recording 85 of 171: about to read 00084.wav
# recording 86 of 171: about to read 00085.wav
# recording 87 of 171: about to read 00086.wav
# recording 88 of 171: about to read 00087.wav
# recording 89 of 171: about to read 00088.wav
# recording 90 of 171: about to read 00089.wav
# recording 91 of 171: about to read 00090.wav
# recording 92 of 171: about to read 00091.wav
# recording 93 of 171: about to read 00092.wav
# recording 94 of 171: about to read 00093.wav
# recording 95 of 171: about to read 00094.wav
# recording 96 of 171: about to read 00095.wav
# recording 97 of 171: about to read 00096.wav
# recording 98 of 171: about to read 00097.wav
# recording 99 of 171: about to read 00098.wav
# recording 100 of 171: about to read 00099.wav
# recording 101 of 171: about to read 00100.wav
# recording 102 of 171: about to read 00101.wav
# recording 103 of 171: about to read 00102.wav
# recording 104 of 171: about to read 00103.wav
# recording 105 of 171: about to read 00104.wav
# recording 106 of 171: about to read 00105.wav
# recording 107 of 171: about to read 00106.wav
# recording 108 of 171: about to read 00107.wav
# recording 109 of 171: about to read 00108.wav
# recording 110 of 171: about to read 00109.wav
# recording 111 of 171: about to read 00110.wav
# recording 112 of 171: about to read 00111.wav
# recording 113 of 171: about to read 00112.wav
# recording 114 of 171: about to read 00113.wav
# recording 115 of 171: about to read 00114.wav
# recording 116 of 171: about to read 00115.wav
# recording 117 of 171: about to read 00116.wav
# recording 118 of 171: about to read 00117.wav
# recording 119 of 171: about to read 00118.wav
# recording 120 of 171: about to read 00119.wav
# recording 121 of 171: about to read 00120.wav
# recording 122 of 171: about to read 00121.wav
# recording 123 of 171: about to read 00122.wav
# recording 124 of 171: about to read 00123.wav
# recording 125 of 171: about to read 00124.wav
# recording 126 of 171: about to read 00125.wav
# recording 127 of 171: about to read 00126.wav
# recording 128 of 171: about to read 00127.wav
# recording 129 of 171: about to read 00128.wav
# recording 130 of 171: about to read 00129.wav
# recording 131 of 171: about to read 00130.wav
# recording 132 of 171: about to read 00131.wav
# recording 133 of 171: about to read 00132.wav
# recording 134 of 171: about to read 00133.wav
# recording 135 of 171: about to read 00134.wav
# recording 136 of 171: about to read 00135.wav
# recording 137 of 171: about to read 00136.wav
# recording 138 of 171: about to read 00137.wav
# recording 139 of 171: about to read 00138.wav
# recording 140 of 171: about to read 00139.wav
# recording 141 of 171: about to read 00140.wav
# recording 142 of 171: about to read 00141.wav
# recording 143 of 171: about to read 00142.wav
# recording 144 of 171: about to read 00143.wav
# recording 145 of 171: about to read 00144.wav
# recording 146 of 171: about to read 00145.wav
# recording 147 of 171: about to read 00146.wav
# recording 148 of 171: about to read 00147.wav
# recording 149 of 171: about to read 00148.wav
# recording 150 of 171: about to read 00149.wav
# recording 151 of 171: about to read 00150.wav
# recording 152 of 171: about to read 00151.wav
# recording 153 of 171: about to read 00152.wav
# recording 154 of 171: about to read 00153.wav
# recording 155 of 171: about to read 00154.wav
# recording 156 of 171: about to read 00155.wav
# recording 157 of 171: about to read 00156.wav
# recording 158 of 171: about to read 00157.wav
# recording 159 of 171: about to read 00158.wav
# recording 160 of 171: about to read 00159.wav
# recording 161 of 171: about to read 00160.wav
# recording 162 of 171: about to read 00161.wav
# recording 163 of 171: about to read 00162.wav
# recording 164 of 171: about to read 00163.wav
# recording 165 of 171: about to read 00164.wav
# recording 166 of 171: about to read 00165.wav
# recording 167 of 171: about to read 00166.wav
# recording 168 of 171: about to read 00167.wav
# recording 169 of 171: about to read 00168.wav
# recording 170 of 171: about to read 00169.wav
# recording 171 of 171: about to read 00170.wav

# %%
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa
import os
from scipy import signal
import pandas as pd
from PIL import Image, ImageDraw

# %%
# root_dir of where to put annotated spectrograms, etc.
root_dir = '../../ROIs/'

# Where the computed spectrograms are located.
spectrogram_dir = '../../Spectrograms/'

# Where the ROI .csv files are located.
rois_dir = '../../ROIs/'

# The .csv file with the info about the ROIs.
rois_info_file = '../../ROIs/birds.csv'

# Read the ROI info.
rois_info = pd.read_csv(rois_info_file)

n_birds = 5;

# %%
# For each bird, read the ROI file and process the ROIs.
#for i in range(1):
for i in range(n_birds):
    print(i)
    # Read ROI .csv file for this bird.
    roi_csv_file = rois_dir + rois_info['roi_file'][i]
    bird_rois_info = pd.read_csv(roi_csv_file);
#    print(bird_rois_info.head(5))

    n_rois = rois_info['roi_count'][i]
    
    # Process each ROI for this bird.
    for j in range(n_rois):
#    for j in range(2):
#        print(j)
        # Always get original spectroram.
        recording = bird_rois_info['recording'][j]
        spectrogram = recording + '.png'
        spectrogram_filename = spectrogram_dir + spectrogram
        spectrogram_image = plt.imread(spectrogram_filename)
#        plt.imshow(spectrogram_image,cmap='gray')
        
        # Check to see if this spectrogram has already been marked with an ROI.
        spectrogram_roi = recording + '.roi.png'
        spectrogram_roi_filename = root_dir + rois_info['bird'][i] + '/' + spectrogram_roi
#        print(spectrogram_roi_filename)
        
        if os.path.exists(spectrogram_roi_filename):
            # Read already marked up spectrogram.
            spectrogram_roi_image_PIL = Image.open(spectrogram_roi_filename);
        else:
            spectrogram_roi_image_PIL = Image.open(spectrogram_filename);

        # Get size of spectrogram.
        n_rows = np.shape(spectrogram_image)[0]
        n_cols = np.shape(spectrogram_image)[1]
            
        # Get time and frequency coordinates of spectrogram from _info.txt file.
        spectrogram_info = recording + '_info.txt'
        spectrogram_info_filename = spectrogram_dir + spectrogram_info
        spectrograminfo_file = open(spectrogram_info_filename,'r')

        time_coords = np.zeros(n_cols)
        for x in range(n_cols):
            time_coords[x] = spectrograminfo_file.readline()
        freq_coords = np.zeros(n_rows)
        for x in range(n_rows):
            freq_coords[x] = spectrograminfo_file.readline()
        spectrograminfo_file.close()
        # Reverse.
        freq_coords = np.flip(freq_coords)
        
        # Find pixel bounds of ROI.
        top_left_row = np.where(freq_coords < bird_rois_info['y2'][j])
 #       print(top_left_row[0][0])
        bottom_right_row = np.where(freq_coords < bird_rois_info['y1'][j])
 #       print(bottom_right_row[0][0])
        top_left_col = np.where(time_coords > bird_rois_info['x1'][j])
#        print(top_left_col[0][0])
        bottom_right_col = np.where(time_coords > bird_rois_info['x2'][j])
#        print(bottom_right_col[0][0])
        width = bottom_right_col[0][0] - top_left_col[0][0] + 1;
        height = bottom_right_row[0][0] - top_left_row[0][0] + 1;
#        print(width)
#        print(height)
        
        # Draw rectangle.
        img1 = ImageDraw.Draw(spectrogram_roi_image_PIL)  
        img1.rectangle([(top_left_col[0][0],top_left_row[0][0]),(bottom_right_col[0][0],bottom_right_row[0][0])], outline ='white')
#        spectrogram_roi_image_PIL.show()
        
        # Save spectrogram with marked ROIs.
        spectrogram_roi_image_PIL.save(spectrogram_roi_filename)
        
        # Extract and save ROI.
        image_roi = spectrogram_image[top_left_row[0][0]-1:bottom_right_row[0][0]-1, top_left_col[0][0]-1:bottom_right_col[0][0]-1]
        image_roi_filename = root_dir+rois_info['bird'][i]+'/ROIs/'+rois_info['bird'][i]+'_'+repr(bird_rois_info['id'][j])+'.png'
        print(image_roi_filename)
        plt.imsave(image_roi_filename, image_roi, cmap='gray')
# Out:
# 0
# ../../ROIs/DEJU/ROIs/DEJU_10888.png
# ../../ROIs/DEJU/ROIs/DEJU_10889.png
# ../../ROIs/DEJU/ROIs/DEJU_10890.png
# ../../ROIs/DEJU/ROIs/DEJU_10891.png
# ../../ROIs/DEJU/ROIs/DEJU_10892.png
# ../../ROIs/DEJU/ROIs/DEJU_10893.png
# ../../ROIs/DEJU/ROIs/DEJU_10894.png
# ../../ROIs/DEJU/ROIs/DEJU_11748.png
# ../../ROIs/DEJU/ROIs/DEJU_11749.png
# ../../ROIs/DEJU/ROIs/DEJU_11750.png
# ../../ROIs/DEJU/ROIs/DEJU_14505.png
# ../../ROIs/DEJU/ROIs/DEJU_14507.png
# ../../ROIs/DEJU/ROIs/DEJU_14537.png
# ../../ROIs/DEJU/ROIs/DEJU_14538.png
# ../../ROIs/DEJU/ROIs/DEJU_14539.png
# ../../ROIs/DEJU/ROIs/DEJU_14540.png
# ../../ROIs/DEJU/ROIs/DEJU_14541.png
# ../../ROIs/DEJU/ROIs/DEJU_14542.png
# ../../ROIs/DEJU/ROIs/DEJU_14543.png
# ../../ROIs/DEJU/ROIs/DEJU_14544.png
# ../../ROIs/DEJU/ROIs/DEJU_14545.png
# ../../ROIs/DEJU/ROIs/DEJU_14546.png
# ../../ROIs/DEJU/ROIs/DEJU_14547.png
# ../../ROIs/DEJU/ROIs/DEJU_14548.png
# ../../ROIs/DEJU/ROIs/DEJU_14587.png
# ../../ROIs/DEJU/ROIs/DEJU_33808.png
# 1
# ../../ROIs/PSFL/ROIs/PSFL_12481.png
# ../../ROIs/PSFL/ROIs/PSFL_12483.png
# ../../ROIs/PSFL/ROIs/PSFL_12484.png
# ../../ROIs/PSFL/ROIs/PSFL_12487.png
# ../../ROIs/PSFL/ROIs/PSFL_12488.png
# ../../ROIs/PSFL/ROIs/PSFL_12489.png
# ../../ROIs/PSFL/ROIs/PSFL_12491.png
# ../../ROIs/PSFL/ROIs/PSFL_12497.png
# ../../ROIs/PSFL/ROIs/PSFL_12498.png
# ../../ROIs/PSFL/ROIs/PSFL_12500.png
# ../../ROIs/PSFL/ROIs/PSFL_12501.png
# ../../ROIs/PSFL/ROIs/PSFL_12507.png
# ../../ROIs/PSFL/ROIs/PSFL_12515.png
# ../../ROIs/PSFL/ROIs/PSFL_12516.png
# ../../ROIs/PSFL/ROIs/PSFL_12518.png
# ../../ROIs/PSFL/ROIs/PSFL_12521.png
# ../../ROIs/PSFL/ROIs/PSFL_12522.png
# ../../ROIs/PSFL/ROIs/PSFL_12524.png
# ../../ROIs/PSFL/ROIs/PSFL_12525.png
# ../../ROIs/PSFL/ROIs/PSFL_12528.png
# ../../ROIs/PSFL/ROIs/PSFL_12529.png
# ../../ROIs/PSFL/ROIs/PSFL_12530.png
# ../../ROIs/PSFL/ROIs/PSFL_14501.png
# ../../ROIs/PSFL/ROIs/PSFL_14502.png
# ../../ROIs/PSFL/ROIs/PSFL_14503.png
# 2
# ../../ROIs/SPTO/ROIs/SPTO_13613.png
# ../../ROIs/SPTO/ROIs/SPTO_13614.png
# ../../ROIs/SPTO/ROIs/SPTO_13615.png
# ../../ROIs/SPTO/ROIs/SPTO_13626.png
# ../../ROIs/SPTO/ROIs/SPTO_13627.png
# ../../ROIs/SPTO/ROIs/SPTO_13629.png
# ../../ROIs/SPTO/ROIs/SPTO_13630.png
# ../../ROIs/SPTO/ROIs/SPTO_13631.png
# ../../ROIs/SPTO/ROIs/SPTO_13632.png
# ../../ROIs/SPTO/ROIs/SPTO_13633.png
# ../../ROIs/SPTO/ROIs/SPTO_13635.png
# ../../ROIs/SPTO/ROIs/SPTO_13636.png
# ../../ROIs/SPTO/ROIs/SPTO_13638.png
# ../../ROIs/SPTO/ROIs/SPTO_13640.png
# ../../ROIs/SPTO/ROIs/SPTO_13641.png
# ../../ROIs/SPTO/ROIs/SPTO_13642.png
# ../../ROIs/SPTO/ROIs/SPTO_14133.png
# ../../ROIs/SPTO/ROIs/SPTO_14134.png
# ../../ROIs/SPTO/ROIs/SPTO_14135.png
# ../../ROIs/SPTO/ROIs/SPTO_14136.png
# ../../ROIs/SPTO/ROIs/SPTO_14137.png
# ../../ROIs/SPTO/ROIs/SPTO_14138.png
# ../../ROIs/SPTO/ROIs/SPTO_14139.png
# ../../ROIs/SPTO/ROIs/SPTO_14140.png
# ../../ROIs/SPTO/ROIs/SPTO_14141.png
# ../../ROIs/SPTO/ROIs/SPTO_14142.png
# ../../ROIs/SPTO/ROIs/SPTO_14143.png
# ../../ROIs/SPTO/ROIs/SPTO_14144.png
# ../../ROIs/SPTO/ROIs/SPTO_14145.png
# ../../ROIs/SPTO/ROIs/SPTO_14146.png
# ../../ROIs/SPTO/ROIs/SPTO_14147.png
# ../../ROIs/SPTO/ROIs/SPTO_14148.png
# ../../ROIs/SPTO/ROIs/SPTO_14149.png
# ../../ROIs/SPTO/ROIs/SPTO_14150.png
# ../../ROIs/SPTO/ROIs/SPTO_14151.png
# ../../ROIs/SPTO/ROIs/SPTO_14152.png
# ../../ROIs/SPTO/ROIs/SPTO_14153.png
# 3
# ../../ROIs/WAVI/ROIs/WAVI_12855.png
# ../../ROIs/WAVI/ROIs/WAVI_12860.png
# ../../ROIs/WAVI/ROIs/WAVI_12864.png
# ../../ROIs/WAVI/ROIs/WAVI_12874.png
# ../../ROIs/WAVI/ROIs/WAVI_12876.png
# ../../ROIs/WAVI/ROIs/WAVI_12879.png
# ../../ROIs/WAVI/ROIs/WAVI_12881.png
# ../../ROIs/WAVI/ROIs/WAVI_12883.png
# ../../ROIs/WAVI/ROIs/WAVI_12885.png
# ../../ROIs/WAVI/ROIs/WAVI_12887.png
# ../../ROIs/WAVI/ROIs/WAVI_12890.png
# ../../ROIs/WAVI/ROIs/WAVI_12892.png
# ../../ROIs/WAVI/ROIs/WAVI_12893.png
# ../../ROIs/WAVI/ROIs/WAVI_12895.png
# ../../ROIs/WAVI/ROIs/WAVI_12897.png
# ../../ROIs/WAVI/ROIs/WAVI_12900.png
# ../../ROIs/WAVI/ROIs/WAVI_12902.png
# ../../ROIs/WAVI/ROIs/WAVI_12905.png
# ../../ROIs/WAVI/ROIs/WAVI_12908.png
# ../../ROIs/WAVI/ROIs/WAVI_12909.png
# ../../ROIs/WAVI/ROIs/WAVI_12910.png
# ../../ROIs/WAVI/ROIs/WAVI_12912.png
# ../../ROIs/WAVI/ROIs/WAVI_12916.png
# ../../ROIs/WAVI/ROIs/WAVI_12917.png
# ../../ROIs/WAVI/ROIs/WAVI_13193.png
# ../../ROIs/WAVI/ROIs/WAVI_13194.png
# ../../ROIs/WAVI/ROIs/WAVI_13195.png
# ../../ROIs/WAVI/ROIs/WAVI_15607.png
# ../../ROIs/WAVI/ROIs/WAVI_15608.png
# ../../ROIs/WAVI/ROIs/WAVI_15609.png
# ../../ROIs/WAVI/ROIs/WAVI_15610.png
# ../../ROIs/WAVI/ROIs/WAVI_15611.png
# ../../ROIs/WAVI/ROIs/WAVI_15612.png
# ../../ROIs/WAVI/ROIs/WAVI_15613.png
# ../../ROIs/WAVI/ROIs/WAVI_15615.png
# ../../ROIs/WAVI/ROIs/WAVI_15616.png
# ../../ROIs/WAVI/ROIs/WAVI_15617.png
# ../../ROIs/WAVI/ROIs/WAVI_15618.png
# ../../ROIs/WAVI/ROIs/WAVI_15619.png
# ../../ROIs/WAVI/ROIs/WAVI_15620.png
# ../../ROIs/WAVI/ROIs/WAVI_15621.png
# ../../ROIs/WAVI/ROIs/WAVI_15642.png
# ../../ROIs/WAVI/ROIs/WAVI_15643.png
# ../../ROIs/WAVI/ROIs/WAVI_15644.png
# ../../ROIs/WAVI/ROIs/WAVI_15645.png
# ../../ROIs/WAVI/ROIs/WAVI_15646.png
# ../../ROIs/WAVI/ROIs/WAVI_15647.png
# ../../ROIs/WAVI/ROIs/WAVI_15648.png
# ../../ROIs/WAVI/ROIs/WAVI_15649.png
# ../../ROIs/WAVI/ROIs/WAVI_15650.png
# ../../ROIs/WAVI/ROIs/WAVI_15651.png
# ../../ROIs/WAVI/ROIs/WAVI_15653.png
# ../../ROIs/WAVI/ROIs/WAVI_15656.png
# ../../ROIs/WAVI/ROIs/WAVI_15657.png
# ../../ROIs/WAVI/ROIs/WAVI_15658.png
# ../../ROIs/WAVI/ROIs/WAVI_15659.png
# ../../ROIs/WAVI/ROIs/WAVI_15660.png
# ../../ROIs/WAVI/ROIs/WAVI_15661.png
# 4
# ../../ROIs/WIWA/ROIs/WIWA_13012.png
# ../../ROIs/WIWA/ROIs/WIWA_13013.png
# ../../ROIs/WIWA/ROIs/WIWA_13014.png
# ../../ROIs/WIWA/ROIs/WIWA_13015.png
# ../../ROIs/WIWA/ROIs/WIWA_13018.png
# ../../ROIs/WIWA/ROIs/WIWA_13019.png
# ../../ROIs/WIWA/ROIs/WIWA_13020.png
# ../../ROIs/WIWA/ROIs/WIWA_13021.png
# ../../ROIs/WIWA/ROIs/WIWA_13022.png
# ../../ROIs/WIWA/ROIs/WIWA_13023.png
# ../../ROIs/WIWA/ROIs/WIWA_13024.png
# ../../ROIs/WIWA/ROIs/WIWA_13025.png
# ../../ROIs/WIWA/ROIs/WIWA_13026.png
# ../../ROIs/WIWA/ROIs/WIWA_13027.png
# ../../ROIs/WIWA/ROIs/WIWA_13028.png
# ../../ROIs/WIWA/ROIs/WIWA_13029.png
# ../../ROIs/WIWA/ROIs/WIWA_13030.png
# ../../ROIs/WIWA/ROIs/WIWA_13031.png
# ../../ROIs/WIWA/ROIs/WIWA_13032.png
# ../../ROIs/WIWA/ROIs/WIWA_13033.png
# ../../ROIs/WIWA/ROIs/WIWA_13036.png
# ../../ROIs/WIWA/ROIs/WIWA_13038.png
# ../../ROIs/WIWA/ROIs/WIWA_13047.png
# ../../ROIs/WIWA/ROIs/WIWA_13049.png
# ../../ROIs/WIWA/ROIs/WIWA_13051.png
# ../../ROIs/WIWA/ROIs/WIWA_13053.png
# ../../ROIs/WIWA/ROIs/WIWA_13055.png
# ../../ROIs/WIWA/ROIs/WIWA_13057.png
# ../../ROIs/WIWA/ROIs/WIWA_13059.png
# ../../ROIs/WIWA/ROIs/WIWA_13060.png
# ../../ROIs/WIWA/ROIs/WIWA_13063.png
# ../../ROIs/WIWA/ROIs/WIWA_13429.png
# ../../ROIs/WIWA/ROIs/WIWA_13430.png
# ../../ROIs/WIWA/ROIs/WIWA_13431.png
# ../../ROIs/WIWA/ROIs/WIWA_13432.png
# ../../ROIs/WIWA/ROIs/WIWA_13433.png
# ../../ROIs/WIWA/ROIs/WIWA_13434.png
# ../../ROIs/WIWA/ROIs/WIWA_13435.png
# ../../ROIs/WIWA/ROIs/WIWA_13436.png
# ../../ROIs/WIWA/ROIs/WIWA_13437.png
# ../../ROIs/WIWA/ROIs/WIWA_13438.png
# ../../ROIs/WIWA/ROIs/WIWA_13439.png
# ../../ROIs/WIWA/ROIs/WIWA_13440.png
# ../../ROIs/WIWA/ROIs/WIWA_13441.png
# ../../ROIs/WIWA/ROIs/WIWA_13442.png
# ../../ROIs/WIWA/ROIs/WIWA_13443.png
# ../../ROIs/WIWA/ROIs/WIWA_13444.png
# ../../ROIs/WIWA/ROIs/WIWA_13445.png
# ../../ROIs/WIWA/ROIs/WIWA_13446.png
# ../../ROIs/WIWA/ROIs/WIWA_13447.png
# ../../ROIs/WIWA/ROIs/WIWA_13448.png
# ../../ROIs/WIWA/ROIs/WIWA_13449.png
# ../../ROIs/WIWA/ROIs/WIWA_13450.png
# ../../ROIs/WIWA/ROIs/WIWA_13451.png
# ../../ROIs/WIWA/ROIs/WIWA_13452.png
# ../../ROIs/WIWA/ROIs/WIWA_13454.png
# ../../ROIs/WIWA/ROIs/WIWA_13455.png
# ../../ROIs/WIWA/ROIs/WIWA_13456.png
# ../../ROIs/WIWA/ROIs/WIWA_13457.png
# ../../ROIs/WIWA/ROIs/WIWA_13458.png
# ../../ROIs/WIWA/ROIs/WIWA_13459.png
# ../../ROIs/WIWA/ROIs/WIWA_13460.png
# ../../ROIs/WIWA/ROIs/WIWA_13461.png
# ../../ROIs/WIWA/ROIs/WIWA_13462.png
# ../../ROIs/WIWA/ROIs/WIWA_13463.png
# ../../ROIs/WIWA/ROIs/WIWA_13464.png
# ../../ROIs/WIWA/ROIs/WIWA_13465.png
# ../../ROIs/WIWA/ROIs/WIWA_13466.png
# ../../ROIs/WIWA/ROIs/WIWA_13467.png
# ../../ROIs/WIWA/ROIs/WIWA_13468.png
# ../../ROIs/WIWA/ROIs/WIWA_13469.png
# ../../ROIs/WIWA/ROIs/WIWA_13470.png
